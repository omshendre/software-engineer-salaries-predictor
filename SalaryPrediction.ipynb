# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('data/updated_file.csv')
print(data["CurrentYear"].value_counts())
# Out:
# CurrentYear
# 2021    83439
# 2022    73268
# Name: count, dtype: int64

# %%
data.head()
# Out:
#                                              Country  \
# 0                                           Slovakia
# 1                                        Netherlands
# 2                                 Russian Federation
# 3                                            Austria
# 4  United Kingdom of Great Britain and Northern I...
#
#                                              EdLevel YearsCodePro  \
# 0  Secondary school (e.g. American high school, G...          NaN
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)          NaN
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)          NaN
# 3    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)          NaN
# 4    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)           10
#
#                                           Employment  ConvertedCompYearly  \
# 0  Independent contractor, freelancer, or self-em...              62268.0
# 1                                 Student, full-time                  NaN
# 2                                 Student, full-time                  NaN
# 3                                 Employed full-time                  NaN
# 4  Independent contractor, freelancer, or self-em...                  NaN
#
#    CurrentYear
# 0         2021
# 1         2021
# 2         2021
# 3         2021
# 4         2021

# %%
column_names = data.columns.tolist()
for col in column_names:
    print(col)
# Out:
# Country
# EdLevel
# YearsCodePro
# Employment
# ConvertedCompYearly
# CurrentYear

# %%
# df["CurrentYear"].value_counts()
# df.head()

# %%
df = data[['Country','EdLevel','YearsCodePro','Employment','ConvertedCompYearly','CurrentYear',]]
df = df.rename({'ConvertedCompYearly':'Salary'},axis =1)
df.head()
# Out:
#                                              Country  \
# 0                                           Slovakia
# 1                                        Netherlands
# 2                                 Russian Federation
# 3                                            Austria
# 4  United Kingdom of Great Britain and Northern I...
#
#                                              EdLevel YearsCodePro  \
# 0  Secondary school (e.g. American high school, G...          NaN
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)          NaN
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)          NaN
# 3    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)          NaN
# 4    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)           10
#
#                                           Employment   Salary  CurrentYear
# 0  Independent contractor, freelancer, or self-em...  62268.0         2021
# 1                                 Student, full-time      NaN         2021
# 2                                 Student, full-time      NaN         2021
# 3                                 Employed full-time      NaN         2021
# 4  Independent contractor, freelancer, or self-em...      NaN         2021

# %%
df["CurrentYear"].value_counts()
# Out:
# CurrentYear
# 2021    83439
# 2022    73268
# Name: count, dtype: int64

# %%
df = df[df['Salary'].notnull()]
df.head()
# Out:
#      Country                                            EdLevel YearsCodePro  \
# 0   Slovakia  Secondary school (e.g. American high school, G...          NaN
# 9     Sweden    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)            4
# 11     Spain       Bachelor’s degree (B.A., B.S., B.Eng., etc.)            5
# 12   Germany    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)            6
# 16    Turkey       Bachelor’s degree (B.A., B.S., B.Eng., etc.)            2
#
#                                            Employment   Salary  CurrentYear
# 0   Independent contractor, freelancer, or self-em...  62268.0         2021
# 9                                  Employed full-time  51552.0         2021
# 11                                 Employed full-time  46482.0         2021
# 12                                 Employed full-time  77290.0         2021
# 16                                 Employed full-time  17748.0         2021

# %%
df["CurrentYear"].value_counts()
# Out:
# CurrentYear
# 2021    46844
# 2022    38071
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 84915 entries, 0 to 156560
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       84915 non-null  object
#  1   EdLevel       84877 non-null  object
#  2   YearsCodePro  84326 non-null  object
#  3   Employment    84898 non-null  object
#  4   Salary        84915 non-null  float64
#  5   CurrentYear   84915 non-null  int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.5+ MB

# %%
df["CurrentYear"].value_counts()
# Out:
# CurrentYear
# 2021    46844
# 2022    38071
# Name: count, dtype: int64

# %%
df = df.dropna()

# %%
df["CurrentYear"].value_counts()
# Out:
# CurrentYear
# 2021    46359
# 2022    37919
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Country         0
# EdLevel         0
# YearsCodePro    0
# Employment      0
# Salary          0
# CurrentYear     0
# dtype: int64

# %%
df["CurrentYear"].value_counts()
# Out:
# CurrentYear
# 2021    46359
# 2022    37919
# Name: count, dtype: int64

# %%
df.head()
# Out:
#     Country                                          EdLevel YearsCodePro  \
# 9    Sweden  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)            4
# 11    Spain     Bachelor’s degree (B.A., B.S., B.Eng., etc.)            5
# 12  Germany  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)            6
# 16   Turkey     Bachelor’s degree (B.A., B.S., B.Eng., etc.)            2
# 17   Canada     Bachelor’s degree (B.A., B.S., B.Eng., etc.)            6
#
#             Employment   Salary  CurrentYear
# 9   Employed full-time  51552.0         2021
# 11  Employed full-time  46482.0         2021
# 12  Employed full-time  77290.0         2021
# 16  Employed full-time  17748.0         2021
# 17  Employed full-time  46135.0         2021

# %%
df["CurrentYear"].value_counts()
# Out:
# CurrentYear
# 2021    46359
# 2022    37919
# Name: count, dtype: int64

# %%
df["Employment"].value_counts()
# Out:
# Employment
# Employed full-time                                                                              40211
# Employed, full-time                                                                             31382
# Independent contractor, freelancer, or self-employed                                             7451
# Employed, full-time;Independent contractor, freelancer, or self-employed                         2633
# Employed part-time                                                                               1389
# Employed, part-time                                                                               632
# Independent contractor, freelancer, or self-employed;Employed, part-time                          207
# Employed, full-time;Employed, part-time                                                           151
# Employed, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time      118
# I prefer not to say                                                                                58
# Retired                                                                                            34
# Employed, part-time;Retired                                                                         5
# Independent contractor, freelancer, or self-employed;Retired                                        3
# Employed, full-time;Independent contractor, freelancer, or self-employed;Retired                    3
# Employed, full-time;Retired                                                                         1
# Name: count, dtype: int64

# %%
df = df[(df["Employment"] == "Employed full-time") | (df["Employment"] == "Employed, full-time")]
df = df.drop("Employment", axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 71593 entries, 9 to 156560
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       71593 non-null  object
#  1   EdLevel       71593 non-null  object
#  2   YearsCodePro  71593 non-null  object
#  3   Salary        71593 non-null  float64
#  4   CurrentYear   71593 non-null  int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 3.3+ MB

# %%
df["CurrentYear"].value_counts()
# Out:
# CurrentYear
# 2021    40211
# 2022    31382
# Name: count, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# Country
# United States of America                                17033
# India                                                    5254
# Germany                                                  5135
# United Kingdom of Great Britain and Northern Ireland     4945
# Canada                                                   2802
#                                                         ...
# Djibouti                                                    1
# Dominica                                                    1
# Libyan Arab Jamahiriya                                      1
# Saint Kitts and Nevis                                       1
# Seychelles                                                  1
# Name: count, Length: 172, dtype: int64

# %%
df["CurrentYear"].value_counts()
# Out:
# CurrentYear
# 2021    40211
# 2022    31382
# Name: count, dtype: int64

# %%
def shorten_categories(categories,cutoff):
    categories_map={}
    for i in range(len(categories)):
        if categories.values[i] >= cutoff:
            categories_map[categories.index[i]] = categories.index[i]
        else:
            categories_map[categories.index[i]] = 'Other'
    return categories_map

# %%
df['Country'].value_counts()
# df['CurrentYear'].value_counts()
# Out:
# Country
# United States of America                                17033
# India                                                    5254
# Germany                                                  5135
# United Kingdom of Great Britain and Northern Ireland     4945
# Canada                                                   2802
#                                                         ...
# Djibouti                                                    1
# Dominica                                                    1
# Libyan Arab Jamahiriya                                      1
# Saint Kitts and Nevis                                       1
# Seychelles                                                  1
# Name: count, Length: 172, dtype: int64

# %%
df["CurrentYear"].value_counts()
# Out:
# CurrentYear
# 2021    40211
# 2022    31382
# Name: count, dtype: int64

# %%
country_map = shorten_categories(df['Country'].value_counts(),400)
df['Country'] = df['Country'].map(country_map)
df['Country'].value_counts()
# Out:
# Country
# United States of America                                17033
# Other                                                    8831
# India                                                    5254
# Germany                                                  5135
# United Kingdom of Great Britain and Northern Ireland     4945
# Canada                                                   2802
# France                                                   2522
# Brazil                                                   2354
# Spain                                                    1748
# Netherlands                                              1536
# Australia                                                1525
# Italy                                                    1423
# Poland                                                   1347
# Sweden                                                   1296
# Russian Federation                                       1166
# Switzerland                                               854
# Turkey                                                    819
# Israel                                                    772
# Norway                                                    693
# Denmark                                                   632
# Austria                                                   632
# Mexico                                                    628
# Belgium                                                   613
# Finland                                                   586
# Portugal                                                  571
# Ukraine                                                   562
# Iran, Islamic Republic of...                              547
# South Africa                                              529
# Pakistan                                                  521
# Czech Republic                                            510
# New Zealand                                               509
# Argentina                                                 500
# Greece                                                    489
# Romania                                                   461
# China                                                     430
# Japan                                                     416
# Colombia                                                  402
# Name: count, dtype: int64

# %%
df['CurrentYear'].value_counts()
# Out:
# CurrentYear
# 2021    40211
# 2022    31382
# Name: count, dtype: int64

# %%
fig,ax = plt.subplots(1,1, figsize=(12,7))
df.boxplot('Salary','Country',ax =ax)
plt.suptitle('Salary (US$) V Country')
plt.title('')
plt.ylabel('Salary')
plt.xticks(rotation=90)
plt.show()

# %%
df = df[df["Salary"] <= 250000]
df = df[df["Salary"] >= 10000]
df = df[df['Country'] != 'Other']

# %%
fig,ax = plt.subplots(1,1, figsize=(12,7))
df.boxplot('Salary','Country',ax =ax)
plt.suptitle('Salary (US$) V Country')
plt.title('')
plt.ylabel('Salary')
plt.xticks(rotation=90)
plt.show()

# %%
df["YearsCodePro"].unique()
# Out:
# array(['4', '5', '6', '2', '18', '21', '16', '10', 'Less than 1 year',
#        '3', '15', '12', '8', '17', '1', '14', '26', '34', '11', '25',
#        '24', '22', '13', '9', '20', '7', '39', '27', '23', '30', '19',
#        '35', '33', '37', '43', '40', '29', '38', '31', '42', '28', '46',
#        '32', '36', '47', '45', '44', '41', 'More than 50 years', '50',
#        '49', '48'], dtype=object)

# %%
def clean_experience(x):
    if x =="More than 50 years":
        return 50
    if x == "Less than 1 year":
        return 0.5
    return float(x)
df["YearsCodePro"]=df["YearsCodePro"].apply(clean_experience)

# %%
df["EdLevel"].unique()
# Out:
# array(['Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
#        'Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
#        'Professional degree (JD, MD, etc.)',
#        'Some college/university study without earning a degree',
#        'Other doctoral degree (Ph.D., Ed.D., etc.)', 'Something else',
#        'Primary/elementary school', 'Associate degree (A.A., A.S., etc.)',
#        'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)'],
#       dtype=object)

# %%
def clean_education(x):
    if 'Bachelor’s degree' in x:
        return 'Bachelors'
    if 'Master’s degree' in x:
        return 'Masters'
    if 'Professional degree' in x or 'Other doctoral' in x:
        return 'Post grad'
    return "Less than a Bachelores"
df['EdLevel'] = df["EdLevel"].apply(clean_education)

# %%
df['EdLevel'].unique()
# Out:
# array(['Masters', 'Bachelors', 'Post grad', 'Less than a Bachelores'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le_education = LabelEncoder()
df['EdLevel'] = le_education.fit_transform(df['EdLevel'])
df['EdLevel'].unique()
# Out:
# array([2, 0, 3, 1])

# %%
le_country = LabelEncoder()
df['Country'] = le_country.fit_transform(df['Country'])
df['Country'].unique()
# Out:
# array([30, 29, 12, 32,  5, 11, 31, 34, 27, 16, 33, 35,  4, 13, 17, 20, 24,
#         2, 26,  7,  1,  3, 15, 14,  9, 10,  0, 18, 25, 28, 23, 22,  8,  6,
#        19, 21])

# %%
x = df.drop('Salary',axis =1)
y = df['Salary']

# %%
x.head()
df["CurrentYear"].value_counts()
# Out:
# CurrentYear
# 2021    31197
# 2022    24250
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler

# %%
oversampler = RandomOverSampler(random_state=56)
x_resampled, y_resampled = oversampler.fit_resample(x, y)

# %%
train_x, test_x, train_y, test_y = train_test_split(x_resampled, y_resampled, test_size=0.2, random_state=56)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
from sklearn.linear_model import LinearRegression
linear_reg = LinearRegression()

linear_reg.fit(train_x, train_y)
train_predict = linear_reg.predict(train_x)
test_predict = linear_reg.predict(test_x)

# %%
mse_test = mean_squared_error(test_y, test_predict)
mae_test = mean_absolute_error(test_y, test_predict)
r2_test = r2_score(test_y, test_predict)

print('Mean Squared Error (MSE):', mse_test)
print('Mean Absolute Error (MAE):', mae_test)
print('R-squared (R^2) Score:', r2_test)
# Out:
# Mean Squared Error (MSE): 1945113527.6933374
# Mean Absolute Error (MAE): 33345.29953932528
# R-squared (R^2) Score: 0.17250838482702624

# %%
from sklearn.tree import DecisionTreeRegressor

# Create a Decision Tree regressor
decision_tree_reg = DecisionTreeRegressor(random_state=56)

# Train the Decision Tree regressor
decision_tree_reg.fit(train_x, train_y)

# Make predictions on the training and test sets
train_predict_dt = decision_tree_reg.predict(train_x)
test_predict_dt = decision_tree_reg.predict(test_x)

# %%
mse_test_dt = mean_squared_error(test_y, test_predict_dt)
mae_test_dt = mean_absolute_error(test_y, test_predict_dt)
r2_test_dt = r2_score(test_y, test_predict_dt)

print('Mean Squared Error (MSE):', mse_test_dt)
print('Mean Absolute Error (MAE):', mae_test_dt)
print('R-squared (R^2) Score:', r2_test_dt)
# Out:
# Mean Squared Error (MSE): 861132228.8552288
# Mean Absolute Error (MAE): 18777.057661813513
# R-squared (R^2) Score: 0.6336564993314571

# %%
df["CurrentYear"].value_counts()
# Out:
# CurrentYear
# 2021    31197
# 2022    24250
# Name: count, dtype: int64

# %%
# from sklearn.svm import SVR

# # Create an SVM regressor
# svm_reg = SVR()

# # Train the SVM regressor
# svm_reg.fit(train_x, train_y)

# # Make predictions on the training and test sets
# train_predict_svr = svm_reg.predict(train_x)
# test_predict_svr = svm_reg.predict(test_x)

# %%
# mse_test_svr = mean_squared_error(test_y, test_predict_svr)
# mae_test_svr = mean_absolute_error(test_y, test_predict_svr)
# r2_test_svr = r2_score(test_y, test_predict_svr)

# print('Mean Squared Error (MSE):', mse_test_svr)
# print('Mean Absolute Error (MAE):', mae_test_svr)
# print('R-squared (R^2) Score:', r2_test_svr)

# %%
# from sklearn.ensemble import GradientBoostingRegressor

# # Create a Gradient Boosting regressor
# gradient_boosting_reg = GradientBoostingRegressor(random_state=56)

# # Train the Gradient Boosting regressor
# gradient_boosting_reg.fit(train_x, train_y)

# # Make predictions on the training and test sets
# train_predict_gb = gradient_boosting_reg.predict(train_x)
# test_predict_gb = gradient_boosting_reg.predict(test_x)

# %%
# mse_test_gb = mean_squared_error(test_y, test_predict_gb)
# mae_test_gb = mean_absolute_error(test_y, test_predict_gb)
# r2_test_gb = r2_score(test_y, test_predict_gb)

# print('Mean Squared Error (MSE):', mse_test_gb)
# print('Mean Absolute Error (MAE):', mae_test_gb)
# print('R-squared (R^2) Score:', r2_test_gb)

# %%
# from sklearn.neighbors import KNeighborsRegressor

# # Create a KNN regressor
# knn_reg = KNeighborsRegressor()

# # Train the KNN regressor
# knn_reg.fit(train_x, train_y)

# # Make predictions on the training and test sets
# train_predict_knn = knn_reg.predict(train_x)
# test_predict_knn = knn_reg.predict(test_x)

# %%
# mse_test_knn = mean_squared_error(test_y, test_predict_knn)
# mae_test_knn = mean_absolute_error(test_y, test_predict_knn)
# r2_test_knn = r2_score(test_y, test_predict_knn)

# print('Mean Squared Error (MSE):', mse_test_knn)
# print('Mean Absolute Error (MAE):', mae_test_knn)
# print('R-squared (R^2) Score:', r2_test_knn)

# %%
x
# Out:
#         Country  EdLevel  YearsCodePro  CurrentYear
# 9            30        2           4.0         2021
# 11           29        0           5.0         2021
# 12           12        2           6.0         2021
# 16           32        0           2.0         2021
# 17            5        0           6.0         2021
# ...         ...      ...           ...          ...
# 156552       35        2           5.0         2022
# 156555       35        0          16.0         2022
# 156558       35        0           1.0         2022
# 156559       29        0           2.0         2022
# 156560       34        2           3.0         2022
#
# [55447 rows x 4 columns]

# %%
import numpy as np
X = np.array([["India","Masters",15,2022]])
X
# Out:
# array([['India', 'Masters', '15', '2022']], dtype='<U21')

# %%
X[:, 0] = le_country.transform(X[:, 0])
X[:, 1] = le_education.transform(X[:, 1])
X = X.astype(float)
X
# Out:
# array([[1.400e+01, 2.000e+00, 1.500e+01, 2.022e+03]])

# %%
y_pred = decision_tree_reg.predict(X)
y_pred
# Out:
# /Users/omshendre/miniconda3/envs/spenv/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([62575.71190781])

# %%
import pickle
data = {
    "model":decision_tree_reg,
    "le_country":le_country,
    "le_education":le_education,
}

# %%
with open('model_saved.pkl','wb') as file:
    pickle.dump(data,file)

# %%
with open('model_saved.pkl', 'rb') as file:
    data = pickle.load(file)

regressor_loaded = data["model"]
le_country = data["le_country"]
le_education = data["le_education"]

# %%
y_preded = regressor_loaded.predict(X)
y_preded
# Out:
# /Users/omshendre/miniconda3/envs/spenv/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([62575.71190781])
